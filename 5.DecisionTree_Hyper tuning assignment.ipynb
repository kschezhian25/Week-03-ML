# %%
#Import Libraries#Import Libraries
import pandas as pd

# %%
#Read the excel file
dataset=pd.read_csv("50_Startups.csv")

# %%
dataset=pd.get_dummies(dataset,dtype=int,drop_first=True)

# %%
dataset
# Out:
#     R&D Spend  Administration  Marketing Spend     Profit  State_Florida  \
# 0   165349.20       136897.80        471784.10  192261.83              0
# 1   162597.70       151377.59        443898.53  191792.06              0
# 2   153441.51       101145.55        407934.54  191050.39              1
# 3   144372.41       118671.85        383199.62  182901.99              0
# 4   142107.34        91391.77        366168.42  166187.94              1
# 5   131876.90        99814.71        362861.36  156991.12              0
# 6   134615.46       147198.87        127716.82  156122.51              0
# 7   130298.13       145530.06        323876.68  155752.60              1
# 8   120542.52       148718.95        311613.29  152211.77              0
# 9   123334.88       108679.17        304981.62  149759.96              0
# 10  101913.08       110594.11        229160.95  146121.95              1
# 11  100671.96        91790.61        249744.55  144259.40              0
# ...

# %%
#displaying columns
dataset.columns
# Out:
# Index(['R&D Spend', 'Administration', 'Marketing Spend', 'Profit',
#        'State_Florida', 'State_New York'],
#       dtype='object')

# %%
#Intependent variable Or input variable
independent=dataset[['R&D Spend', 'Administration', 'Marketing Spend','State_Florida', 'State_New York']]

# %%
independent
# Out:
#     R&D Spend  Administration  Marketing Spend  State_Florida  State_New York
# 0   165349.20       136897.80        471784.10              0               1
# 1   162597.70       151377.59        443898.53              0               0
# 2   153441.51       101145.55        407934.54              1               0
# 3   144372.41       118671.85        383199.62              0               1
# 4   142107.34        91391.77        366168.42              1               0
# 5   131876.90        99814.71        362861.36              0               1
# 6   134615.46       147198.87        127716.82              0               0
# 7   130298.13       145530.06        323876.68              1               0
# 8   120542.52       148718.95        311613.29              0               1
# 9   123334.88       108679.17        304981.62              0               0
# 10  101913.08       110594.11        229160.95              1               0
# ...

# %%
#dependent variable  OR Output Variable
dependent=dataset[["Profit"]]

# %%
#Train and Test(Split)
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(independent,dependent,test_size=0.30,random_state=0)

# %%
##############################USING squared_error and best########################################################

# %%
#Model creation.created using training set -------------->Decision Tree<----------------------------------------
from sklearn.tree import DecisionTreeRegressor
regressor= DecisionTreeRegressor(criterion='squared_error',splitter='best')
regressor.fit(x_train, y_train)
############regressor will hold the model---fit method
# Out:
# DecisionTreeRegressor()

# %%
import matplotlib.pyplot as plt
from sklearn import tree
tree.plot_tree(regressor)
plt.show()

# %%
#predicting
y_pred=regressor.predict(x_test)

# %%
#validating
from sklearn.metrics import r2_score
r_score=r2_score(y_test,y_pred)

# %%
r_score
# Out:
# 0.9188658493351406

# %%
############################################USING friedman_mse and best##########################################

# %%
#Model creation.created using training set -------------->Friedman_mse<----------------------------------------
from sklearn.tree import DecisionTreeRegressor
regressor= DecisionTreeRegressor(criterion='friedman_mse',splitter='best')
regressor.fit(x_train, y_train)
############regressor will hold the model---fit method
# Out:
# DecisionTreeRegressor(criterion='friedman_mse')

# %%
import matplotlib.pyplot as plt
from sklearn import tree
tree.plot_tree(regressor)
plt.show()

# %%
#predicting
y_pred=regressor.predict(x_test)

# %%
#validating
from sklearn.metrics import r2_score
r_score=r2_score(y_test,y_pred)

# %%
r_score
# Out:
# 0.907281030654525

# %%
###################################USING absolute_error and best######################################################

# %%
#Model creation.created using training set -------------->absolute_error<----------------------------------------
from sklearn.tree import DecisionTreeRegressor
regressor= DecisionTreeRegressor(criterion='absolute_error',splitter='best')
regressor.fit(x_train, y_train)
############regressor will hold the model---fit method
# Out:
# DecisionTreeRegressor(criterion='absolute_error')

# %%
#predicting
y_pred=regressor.predict(x_test)

# %%
#validating
from sklearn.metrics import r2_score
r_score=r2_score(y_test,y_pred)

# %%
r_score
# Out:
# 0.9674254950913761

# %%
############################################USING poisson and best#####################################################

# %%
#Model creation.created using training set -------------->poisson<----------------------------------------
from sklearn.tree import DecisionTreeRegressor
regressor= DecisionTreeRegressor(criterion='poisson',splitter='best')
regressor.fit(x_train, y_train)
############regressor will hold the model---fit method
# Out:
# DecisionTreeRegressor(criterion='poisson')

# %%
#predicting
y_pred=regressor.predict(x_test)

# %%
#validating
from sklearn.metrics import r2_score
r_score=r2_score(y_test,y_pred)

# %%
r_score
# Out:
# 0.9158584753118286

# %%
##############################USING squared_error and best########################################################

# %%
from sklearn.tree import DecisionTreeRegressor
regressor= DecisionTreeRegressor(criterion='squared_error',splitter='random')
regressor.fit(x_train, y_train)
# Out:
# DecisionTreeRegressor(splitter='random')

# %%
#predicting
y_pred=regressor.predict(x_test)

# %%
#validating
from sklearn.metrics import r2_score
r_score=r2_score(y_test,y_pred)

# %%
r_score
# Out:
# 0.8719506298899377

# %%
######################################################################################################################

# %%
############################################USING friedman_mse and random##########################################

# %%
from sklearn.tree import DecisionTreeRegressor
regressor= DecisionTreeRegressor(criterion='friedman_mse',splitter='random')
regressor.fit(x_train, y_train)
# Out:
# DecisionTreeRegressor(criterion='friedman_mse', splitter='random')

# %%
#predicting
y_pred=regressor.predict(x_test)

# %%
#validating
from sklearn.metrics import r2_score
r_score=r2_score(y_test,y_pred)

# %%
r_score
# Out:
# 0.8126122754059757

# %%
######################################################################################################################

# %%
############################################USING absolute_error and random##########################################

# %%
from sklearn.tree import DecisionTreeRegressor
regressor= DecisionTreeRegressor(criterion='absolute_error',splitter='random')
regressor.fit(x_train, y_train)
# Out:
# DecisionTreeRegressor(criterion='absolute_error', splitter='random')

# %%
#predicting
y_pred=regressor.predict(x_test)

# %%
#validating
from sklearn.metrics import r2_score
r_score=r2_score(y_test,y_pred)

# %%
r_score
# Out:
# 0.8982172976630635

# %%
######################################################################################################################

# %%
############################################USING poisson and random##########################################

# %%
from sklearn.tree import DecisionTreeRegressor
regressor= DecisionTreeRegressor(criterion='poisson',splitter='random')
regressor.fit(x_train, y_train)
# Out:
# DecisionTreeRegressor(criterion='poisson', splitter='random')

# %%
#predicting
y_pred=regressor.predict(x_test)

# %%
#validating
from sklearn.metrics import r2_score
r_score=r2_score(y_test,y_pred)

# %%
r_score
# Out:
# 0.9155236481257958

# %%
############################################USING friedman_mse and random##########################################
